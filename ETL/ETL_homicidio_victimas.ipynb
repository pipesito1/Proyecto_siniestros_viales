# %%
import pandas as pd

# %%
homicidios_victimas = pd.read_excel('../dataset/homicidios.xlsx',sheet_name='VICTIMAS')

# %%
homicidios_victimas.head(3)
# Out:
#     ID_hecho      FECHA  AAAA  MM  DD        ROL VICTIMA       SEXO EDAD  \
# 0  2016-0001 2016-01-01  2016   1   1  CONDUCTOR    MOTO  MASCULINO   19
# 1  2016-0002 2016-01-02  2016   1   2  CONDUCTOR    AUTO  MASCULINO   70
# 2  2016-0003 2016-01-03  2016   1   3  CONDUCTOR    MOTO  MASCULINO   30
#
#    FECHA_FALLECIMIENTO
# 0  2016-01-01 00:00:00
# 1  2016-01-02 00:00:00
# 2  2016-01-03 00:00:00

# %% [markdown]
# ID_hecho, FECHA, ROL, VICTIMA, SEXO, EDAD

# %%
homicidios_victimas.shape
# Out:
# (717, 10)

# %%
homicidios_victimas2 = homicidios_victimas[['ID_hecho','FECHA','AAAA','MM','DD','ROL','VICTIMA','SEXO','EDAD']]
homicidios_victimas2.head(3)
# Out:
#     ID_hecho      FECHA  AAAA  MM  DD        ROL VICTIMA       SEXO EDAD
# 0  2016-0001 2016-01-01  2016   1   1  CONDUCTOR    MOTO  MASCULINO   19
# 1  2016-0002 2016-01-02  2016   1   2  CONDUCTOR    AUTO  MASCULINO   70
# 2  2016-0003 2016-01-03  2016   1   3  CONDUCTOR    MOTO  MASCULINO   30

# %%
# Identificar valores nulos
valores_nulos = homicidios_victimas2.isnull()
homicidios_victimas2
# Out:
#       ID_hecho      FECHA  AAAA  MM  DD                   ROL VICTIMA  \
# 0    2016-0001 2016-01-01  2016   1   1             CONDUCTOR    MOTO
# 1    2016-0002 2016-01-02  2016   1   2             CONDUCTOR    AUTO
# 2    2016-0003 2016-01-03  2016   1   3             CONDUCTOR    MOTO
# 3    2016-0004 2016-01-10  2016   1  10             CONDUCTOR    MOTO
# 4    2016-0005 2016-01-21  2016   1  21             CONDUCTOR    MOTO
# ..         ...        ...   ...  ..  ..                   ...     ...
# 712  2021-0092 2021-12-12  2021  12  12                PEATON  PEATON
# 713  2021-0093 2021-12-13  2021  12  13  PASAJERO_ACOMPAÑANTE    MOTO
# 714  2021-0094 2021-12-20  2021  12  20  PASAJERO_ACOMPAÑANTE    MOTO
# 715  2021-0095 2021-12-30  2021  12  30             CONDUCTOR    MOTO
# 716  2021-0096 2021-12-15  2021  12  15             CONDUCTOR    AUTO
#
#           SEXO EDAD
# 0    MASCULINO   19
# 1    MASCULINO   70
# 2    MASCULINO   30
# 3    MASCULINO   18
# ...

# %%
homicidios_victimas2.dtypes
# Out:
# ID_hecho            object
# FECHA       datetime64[ns]
# AAAA                 int64
# MM                   int64
# DD                   int64
# ROL                 object
# VICTIMA             object
# SEXO                object
# EDAD                object
# dtype: object

# %%
homicidios_victimas2.to_csv('../dataset/homicidios_victimas.csv')
